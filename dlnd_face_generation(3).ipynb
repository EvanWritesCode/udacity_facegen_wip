# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip
# !nvidia-smi
# Out:
# Thu Nov  7 20:58:39 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.87.00    Driver Version: 418.87.00    CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0    72W / 149W |     16MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms
import matplotlib.pyplot as plt
import torchvision.utils as vutils

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    
#     t = transforms.Compose([transforms.ToTensor(),
#                            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])  # the normalize scales the images from -1 to 1 and we do that manually below
    
    t = transforms.Compose([transforms.ToTensor()])
    
    # TODO: Implement function and return a dataloader
    dataset = datasets.ImageFolder(root=data_dir,
                                  transform=t)
    dataloader = torch.utils.data.DataLoader(dataset,batch_size = batch_size, shuffle=True,num_workers=0)
      
    return dataloader

# %%
    usegpu =False
    ngpu=1
    if torch.cuda.is_available():
        usegpu = True       
    
    device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 32 #128
img_size = 32 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    #npimg = np.array((npimg - np.min(npimg)) / (np.max(npimg) - np.min(npimg)))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))       
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    #x = (x*2) -1
    
    min,max = feature_range
    return x * (max-min) + min

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1

dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9373)
# Max:  tensor(1.)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
        
        self.conv_dim = conv_dim
        
        # complete init function
        #32x32x3  to 16x16x128 to lrelu to 8x8x256 to bn to lrelu to 4x4x512 
        #to bn to lrelu to flatten to fully conn to sigmoid
        
        #torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros')
        
        #input 3x32x32
        self.conv1 = nn.Conv2d(3,conv_dim,kernel_size=4,stride=2,padding=1,bias=False)
        
        #input 32x16x16
        self.conv2 = nn.Conv2d(conv_dim,conv_dim*2,kernel_size=4,stride=2,padding=1,bias=False)
        self.batchnorm1 = nn.BatchNorm2d(conv_dim*2)
        
        #input 64x8x8
        self.conv3 = nn.Conv2d(conv_dim*2,conv_dim*4,kernel_size=4,stride=2,padding=1,bias=False)
        self.batchnorm2 = nn.BatchNorm2d(conv_dim*4)        
        #output
        #128x4x4
        
        #TODO:  try removing this fully connected layer and replacing with another convolutional layer.
        #this is what they did in the original dcgan paper https://arxiv.org/pdf/1511.06434.pdf
        self.fc = nn.Linear(conv_dim*4 *4*4,1) #4x4 image of depth conv_dim*4
#         self.fc = nn.Linear(conv_dim*8*2*2,1) #2x2 image of depth conv_dim*8
        
        #self.conv4 = nn.Conv2d(conv_dim*4,conv_dim,kernel_size=4,stride=2,padding=1,bias=False)
        
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        
        # complete forward function
        out = F.leaky_relu(self.conv1(x),0.2)
        
        out = self.conv2(out)
        out = F.leaky_relu(self.batchnorm1(out),0.2)
        
        out = self.conv3(out)
        out = F.leaky_relu(self.batchnorm2(out),0.2)
        
        #flatten
        out = out.view(-1,self.conv_dim*4*4*4)
        
        #TODO:  try removing this fully connected layer and replacing with another convolutional layer.
        #this is what they did in the original dcgan paper https://arxiv.org/pdf/1511.06434.pdf
        out = self.fc(out)        
        
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        self.conv_dim = conv_dim
        self.z_size = z_size
        
        super(Generator, self).__init__()

        # complete init function
        
        self.fc1 = nn.Linear(z_size, conv_dim*8*2*2)      

#         self.tconv0 = nn.ConvTranspose2d(self.z_size,conv_dim*8,kernel_size=4,stride=1,padding=0,bias=False)
#         self.batchnorm0 = nn.BatchNorm2d(conv_dim*8)       
        
        self.tconv1 = nn.ConvTranspose2d(conv_dim*8,conv_dim*4,kernel_size=4,stride=2,padding=1,bias=False)
        self.batchnorm1 = nn.BatchNorm2d(conv_dim*4)

        self.tconv2= nn.ConvTranspose2d(conv_dim*4,conv_dim*2,kernel_size=4,stride=2,padding=1,bias=False)
        self.batchnorm2 = nn.BatchNorm2d(conv_dim*2)

        self.tconv3= nn.ConvTranspose2d(conv_dim*2,conv_dim,kernel_size=4,stride=2,padding=1,bias=False)
        self.batchnorm3 = nn.BatchNorm2d(conv_dim)
        
        self.tconv4= nn.ConvTranspose2d(conv_dim,3,kernel_size=4,stride=2,padding=1,bias=False)       
        
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        #print(x.shape[0])
        
        out = self.fc1(x)
        out = out.view(-1,self.conv_dim*8,2,2)

#         out = self.tconv0(x)
#         out = F.relu(self.batchnorm0(out))
                
        out = self.tconv1(out)
        #out = F.leaky_relu(self.batchnorm1(out),0.2)
        out = F.relu(self.batchnorm1(out))
        
        out = self.tconv2(out)
        #out = F.leaky_relu(self.batchnorm2(out),0.2)
        out = F.relu(self.batchnorm2(out))
        
        out = self.tconv3(out)
        #out = F.leaky_relu(self.batchnorm2(out),0.2)
        out = F.relu(self.batchnorm3(out))        
        
        out = self.tconv4(out)
        out = F.tanh(out)        
        
        return out
            
            

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    # TODO: Apply initial weights to convolutional and linear layers    
    init_gain=0.02
    print(f"classname: {classname}")
    if classname.find('Conv') > -1 or classname.find('Linear') > -1:
        #from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
        nn.init.normal_(m.weight.data, 0.0, init_gain)      
        
    elif classname.find('BatchNorm2d') > -1: 
        #from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
        nn.init.normal_(m.weight.data, 1.0, init_gain)
        nn.init.constant_(m.bias.data, 0.0)        
        
    else:
        print(f"Classname {classname} not recognized,  not initializing weights for this class")

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# classname: Conv2d
# classname: Conv2d
# classname: BatchNorm2d
# classname: Conv2d
# classname: BatchNorm2d
# classname: Linear
# classname: Discriminator
# Classname Discriminator not recognized,  not initializing weights for this class
# classname: Linear
# classname: ConvTranspose2d
# classname: BatchNorm2d
# classname: ConvTranspose2d
# classname: BatchNorm2d
# classname: ConvTranspose2d
# classname: BatchNorm2d
# classname: ConvTranspose2d
# classname: Generator
# Classname Generator not recognized,  not initializing weights for this class
# Discriminator(
#   (conv1): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc1): Linear(in_features=100, out_features=1024, bias=True)
#   (tconv1): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (tconv2): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (tconv3): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (tconv4): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        # smooth, real labels = 0.9
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
    
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()  #or use nn.BCELoss()  or CrossEntropyLoss()  ?
    
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()  #or use nn.BCELoss()  or CrossEntropyLoss()  ?
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# params
lr = .0002   #.0002 from paper
beta1= .4  #.5 from paper
beta2= .999 

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            d_optimizer.zero_grad()
            # 1. Train the discriminator on real and fake images
            
            if train_on_gpu:
                real_images = real_images.cuda()
            
            #real images
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            #fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            # move x to GPU, if available
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)

            # Compute the discriminator losses on fake images            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)

            # add up loss and perform backprop
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step() 
          

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()

            #fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
                
            fake_images = G(z)
            
            d_fake = D(fake_images)
            
            g_loss = real_loss(d_fake, smooth=True) #using real loss to flip labels, ie loss should be how well the generator fooled the discriminator
            
            g_loss.backward()
            g_optimizer.step()
        
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 10


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   10] | d_loss: 1.3568 | g_loss: 1.7380
# Epoch [    1/   10] | d_loss: 0.1077 | g_loss: 3.7936
# Epoch [    1/   10] | d_loss: 0.0360 | g_loss: 4.1831
# Epoch [    1/   10] | d_loss: 0.0218 | g_loss: 4.3850
# Epoch [    1/   10] | d_loss: 0.0142 | g_loss: 4.6795
# Epoch [    1/   10] | d_loss: 0.0101 | g_loss: 5.0232
# Epoch [    1/   10] | d_loss: 0.0065 | g_loss: 5.1978
# Epoch [    1/   10] | d_loss: 0.0047 | g_loss: 5.5116
# Epoch [    1/   10] | d_loss: 0.0023 | g_loss: 6.0397
# Epoch [    1/   10] | d_loss: 0.0023 | g_loss: 6.1735
# Epoch [    1/   10] | d_loss: 0.0017 | g_loss: 6.4056
# Epoch [    1/   10] | d_loss: 0.0014 | g_loss: 6.4833
# Epoch [    1/   10] | d_loss: 0.0016 | g_loss: 6.3671
# Epoch [    1/   10] | d_loss: 0.0013 | g_loss: 6.3726
# Epoch [    1/   10] | d_loss: 0.0012 | g_loss: 6.5899
# Epoch [    1/   10] | d_loss: 0.0011 | g_loss: 6.8167
# Epoch [    1/   10] | d_loss: 0.0007 | g_loss: 6.9988
# Epoch [    1/   10] | d_loss: 0.0008 | g_loss: 7.2344
# Epoch [    1/   10] | d_loss: 0.0006 | g_loss: 7.3514
# Epoch [    1/   10] | d_loss: 0.0005 | g_loss: 7.3487
# Epoch [    1/   10] | d_loss: 0.0005 | g_loss: 7.3271
# Epoch [    1/   10] | d_loss: 0.0006 | g_loss: 7.1819
# Epoch [    1/   10] | d_loss: 0.0005 | g_loss: 7.3161
# Epoch [    1/   10] | d_loss: 0.0005 | g_loss: 7.3829
# Epoch [    1/   10] | d_loss: 0.0006 | g_loss: 7.3118
# Epoch [    1/   10] | d_loss: 0.0006 | g_loss: 7.2632
# Epoch [    1/   10] | d_loss: 0.0005 | g_loss: 7.2063
# Epoch [    1/   10] | d_loss: 0.0004 | g_loss: 7.3369
# Epoch [    1/   10] | d_loss: 0.0004 | g_loss: 7.7570
# Epoch [    1/   10] | d_loss: 0.0002 | g_loss: 7.9108
# Epoch [    1/   10] | d_loss: 0.0003 | g_loss: 8.0515
# Epoch [    1/   10] | d_loss: 0.0002 | g_loss: 8.0406
# Epoch [    1/   10] | d_loss: 0.0002 | g_loss: 7.9733
# Epoch [    1/   10] | d_loss: 0.0003 | g_loss: 7.9389
# Epoch [    1/   10] | d_loss: 0.0002 | g_loss: 8.1590
# Epoch [    1/   10] | d_loss: 0.0002 | g_loss: 8.1400
# Epoch [    1/   10] | d_loss: 0.0002 | g_loss: 8.1092
# Epoch [    1/   10] | d_loss: 0.0002 | g_loss: 8.2330
# Epoch [    1/   10] | d_loss: 0.0002 | g_loss: 8.5049
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 8.5044
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 8.5174
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 8.7824
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.1090
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 8.9144
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.2196
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.3199
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.5327
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.3729
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.4809
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.4126
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.3652
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.3165
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.4717
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.4528
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.5519
# Epoch [    1/   10] | d_loss: 0.0001 | g_loss: 9.4530
# Epoch [    1/   10] | d_loss: 0.0000 | g_loss: 9.7352
# Epoch [    2/   10] | d_loss: 0.0001 | g_loss: 9.6114
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.7312
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.8273
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.0144
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.9218
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.8474
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.8580
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.8705
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.0704
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.8614
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.9120
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.9236
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.8587
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.0129
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.8940
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.9989
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 9.9255
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.0301
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.3195
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.4518
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.3931
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.5208
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.7648
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.4223
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.5834
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.6056
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.5834
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.7300
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.6950
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.7548
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.9336
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 11.0370
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.8813
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.9784
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.6950
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.7059
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.7711
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.8751
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.9110
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 11.0596
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 11.0499
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 11.1411
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 11.3241
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 11.2642
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.8977
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.7883
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.6565
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.5500
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.5734
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.5347
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.6383
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.7849
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.9350
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 11.0934
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 11.2435
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 11.0942
# Epoch [    2/   10] | d_loss: 0.0000 | g_loss: 10.6660
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 10.9668
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 10.7138
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 10.9495
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 10.9018
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.0138
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.1069
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.1157
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.3031
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.3264
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.3747
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.4540
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.5178
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.3944
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.5717
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.4755
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.3770
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.5060
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.6879
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.6324
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.6698
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.4746
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.4489
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.6689
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.7056
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.8516
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.8435
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.9664
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.8595
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.8861
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.9496
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.8784
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 11.9949
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.1297
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.2695
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.1664
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.2671
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.4136
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.2785
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.3688
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.4825
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.6095
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.3999
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.6453
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.7358
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.7768
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.5456
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.6006
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.3041
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.3772
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.3356
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.4082
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.4734
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.5247
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.8919
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.7477
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.6041
# Epoch [    3/   10] | d_loss: 0.0000 | g_loss: 12.9394
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.8866
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.7839
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.7591
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.0597
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.8564
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.7874
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.6557
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.5177
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.7345
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.7712
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.8637
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.7336
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.8129
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.9466
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.8962
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.8713
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.8762
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.8540
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.6205
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.5023
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.5643
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.6266
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.0690
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.0158
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.9305
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.0959
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.0662
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.1092
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.1364
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.0515
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 12.9942
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.2527
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.1579
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.2450
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.3695
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.4593
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.5112
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.5340
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.4969
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.4695
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.5890
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.4018
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.6897
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.3685
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.3368
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.3723
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.5715
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.5248
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.6693
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.7790
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.8583
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 14.0175
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.9014
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.8327
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 14.0809
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.9125
# Epoch [    4/   10] | d_loss: 0.0000 | g_loss: 13.8895
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.8091
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.8942
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.6898
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.8465
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.7400
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.7558
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.8317
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.6287
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.5848
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.5827
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.6727
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.7963
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.8962
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 13.9177
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.1540
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.1879
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.0423
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.1569
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.2058
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.2466
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.2737
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.4248
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.4863
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.6339
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.7156
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.7559
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.5886
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.6820
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.4721
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.4042
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.5417
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.5859
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.7502
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.6925
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.6105
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.6496
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.5956
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.7088
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9973
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.7991
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9553
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9424
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9880
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9855
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 15.0221
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9984
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9688
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9188
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9270
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 15.1230
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9944
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9349
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9886
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9622
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9495
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.9097
# Epoch [    5/   10] | d_loss: 0.0000 | g_loss: 14.8653
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9017
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.8981
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.8148
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9339
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9571
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9290
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9628
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9724
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9845
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9910
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9109
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0587
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9361
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0462
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0335
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0482
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.1008
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.1237
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0320
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0703
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0058
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0917
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0097
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9176
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.1821
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9614
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9446
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0063
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0374
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0330
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9789
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0240
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9834
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0444
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0766
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9929
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9836
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0292
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0173
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0773
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9816
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0294
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0852
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0477
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0129
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0265
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9956
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0453
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.1379
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.1566
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0000
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0616
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0021
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9775
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 14.9857
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.0570
# Epoch [    6/   10] | d_loss: 0.0000 | g_loss: 15.1779
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1864
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1003
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 14.9943
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0371
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0130
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0877
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0617
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0295
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0476
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0339
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0537
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0164
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.4297
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0846
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 14.9909
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0331
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0466
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0533
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1431
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0565
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0515
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1556
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0737
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0770
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0435
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.2724
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0285
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0489
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0635
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1018
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0101
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0025
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1301
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1127
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1371
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0009
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0484
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1834
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1823
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0378
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1712
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0469
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0101
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.2520
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.4987
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0515
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0416
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0666
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 14.9899
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0795
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.0220
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1734
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.2349
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.2081
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1075
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.1223
# Epoch [    7/   10] | d_loss: 0.0000 | g_loss: 15.4332
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.4426
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2700
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1514
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1533
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0802
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0312
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2165
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1175
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0099
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2554
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2442
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.4098
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.3266
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0669
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0083
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2008
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.3715
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2361
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1763
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1336
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0412
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1352
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2368
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.3421
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.3017
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0844
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0969
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0776
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1082
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0305
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1075
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1676
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1738
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1468
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0359
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2524
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1800
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1563
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.4548
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2434
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2266
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1559
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0117
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0067
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0837
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.3553
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2069
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0354
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1144
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.2681
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.4005
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1205
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.1171
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 14.9990
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.0300
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.3048
# Epoch [    8/   10] | d_loss: 0.0000 | g_loss: 15.3147
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 16.0664
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.7935
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.6261
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.6141
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.4977
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.3801
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.2994
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.3795
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1779
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.2788
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0448
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1704
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.2550
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1094
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0904
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0489
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1111
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0394
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0180
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.2472
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.3217
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1226
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1632
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0608
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0863
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0380
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.2154
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.2032
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0710
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.2367
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0994
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1316
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1306
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1050
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0567
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0968
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.4815
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.5318
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.3963
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.3172
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.3407
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.2025
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1708
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.3036
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1222
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.0643
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1683
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.2070
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1576
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1283
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1923
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1201
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.4120
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.3066
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.3405
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.2114
# Epoch [    9/   10] | d_loss: 0.0000 | g_loss: 15.1432
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 17.9395
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 16.9730
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 16.4790
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 16.0469
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.6489
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.2554
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 16.0110
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.6359
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.2458
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 16.0948
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.4627
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.8265
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1129
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.3973
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.9190
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1851
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.6796
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 16.0718
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.4244
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.8671
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1112
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.5347
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.9586
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1708
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.4231
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1224
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.2049
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1837
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.4972
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.2434
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.0440
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1655
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.0664
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1632
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1895
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 16.1625
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.8884
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.6463
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.4905
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.2970
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1365
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.6283
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.4204
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.2102
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1964
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.2304
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.7970
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.4155
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.0103
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1346
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 16.1533
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.8325
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.5465
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.1806
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 16.5915
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 16.1951
# Epoch [   10/   10] | d_loss: 0.0000 | g_loss: 15.7117

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** Higher res images would be the first thing I would use.  The original celeba uses 64 pixel images and the additional data would allow the network to learn much better and have a deeper convolutional model
# I would also build a deeper network.  The relu/leaky relu activations along with the batchnorm should allow for deeper networks to train

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
